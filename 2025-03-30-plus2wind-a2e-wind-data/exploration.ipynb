# %%
import pandas as pd

# %%
file_path = "data/plant.c0.2021.central-spp.55579.csv"

# %%
pd = pd.read_csv(file_path)

# %% [markdown]
# Using three different meteorological models (ERA5, MERRA2, and HRRR) for US wind plants.

# %%
pd.columns
# Out:
# Index(['gmt', 'ERA5 wind speed (m/s)', 'MERRA2 wind speed (m/s)',
#        'HRRR wind speed (m/s)', 'MERRA2 air density (kg/m^3)',
#        'ERA5 density-corrected wind speed (m/s)',
#        'MERRA2 density-corrected wind speed (m/s)',
#        'HRRR density-corrected wind speed (m/s)', 'ERA5 CF (raw)',
#        'ERA5 CF (density adjusted)', 'ERA5 CF (density and loss adjusted)',
#        'MERRA2 CF (raw)', 'MERRA2 CF (density adjusted)',
#        'MERRA2 CF (density and loss adjusted)', 'HRRR CF (raw)',
#        'HRRR CF (density adjusted)', 'HRRR CF (density and loss adjusted)'],
#       dtype='object')

# %%
len(pd)
# Out:
# 8760

# %%
pd.head(5)
# Out:
#           gmt  ERA5 wind speed (m/s)  MERRA2 wind speed (m/s)  \
# 0  2021010100               7.291724                 7.669465
# 1  2021010101               7.806674                 7.810946
# 2  2021010102               8.054152                 7.013194
# 3  2021010103               8.263297                 7.211975
# 4  2021010104               8.206866                 7.988873
#
#    HRRR wind speed (m/s)  MERRA2 air density (kg/m^3)  \
# 0               8.086479                     1.131564
# 1               9.254623                     1.135049
# 2              10.374216                     1.138534
# 3              10.453988                     1.142019
# 4               9.515903                     1.142819
#
#    ERA5 density-corrected wind speed (m/s)  \
# 0                                 7.101409
# 1                                 7.610716
# 2                                 7.860011
# 3                                 8.072334
# ...

# %% [markdown]
# This dataset covers New Mexico but there are also data covering other areas, spanning the entire US
